# %%
# getting photo using web get
# !wget "https://www.princeton.edu/sites/default/files/styles/half_2x/public/images/2022/02/KOA_Nassau_2697x1517.jpg"

# rename it to dog.jpg
# Out:
# --2022-08-25 15:09:29--  https://www.princeton.edu/sites/default/files/styles/half_2x/public/images/2022/02/KOA_Nassau_2697x1517.jpg
# Resolving www.princeton.edu (www.princeton.edu)... 104.18.5.101, 104.18.4.101
# Connecting to www.princeton.edu (www.princeton.edu)|104.18.5.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 211690 (207K) [image/jpeg]
# Saving to: 'KOA_Nassau_2697x1517.jpg.1'
#
#      0K .......... .......... .......... .......... .......... 24% 11.4M 0s
#     50K .......... .......... .......... .......... .......... 48%  735K 0s
#    100K .......... .......... .......... .......... .......... 72% 3.48M 0s
#    150K .......... .......... .......... .......... .......... 96% 1.73M 0s
#    200K ......                                                100% 37.8M=0.1s
#
# 2022-08-25 15:09:30 (1.76 MB/s) - 'KOA_Nassau_2697x1517.jpg.1' saved [211690/211690]

# %%
# importing libraries for image processing
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img =mpimg.imread('dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
img_plot =plt.imshow(img)
plt.show()

# %%
from PIL import Image

# %%
img =Image.open('dog.jpg')
img_resized=img.resize((200,200))

# %%
img_resized.save("img_resized.jpg")

# %%
img_resized
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x1F67FA0C4C0>

# %%
type(img_resized)
# Out:
# PIL.Image.Image

# %%
import cv2

# %%
img =cv2.imread('dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
grayscale_img=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
grayscale_img.shape
# Out:
# (1080, 1920)

# %%
# Saving the image
cv2.imwrite('dog_grayscale.jpg',grayscale_img)
# Out:
# True

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19176/651912209.py in <module>
# ----> 1 from google.colab.patches import cv2_imshow
#
# ModuleNotFoundError: No module named 'google.colab'
