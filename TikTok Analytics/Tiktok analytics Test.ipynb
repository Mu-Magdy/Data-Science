# %% [markdown]
# # Exploratory analysis

# %%
import pandas as pd

# %%
df =pd.read_json('export.json')

# %%
df.head()
# Out:
#                     id                                               desc  \
# 0  6942564167555501056  What do you mean?! #ironman #marvel #fyp #popv...
# 1  6908033755215121408           These people do not exist 🤯 #AI #ML #FYP
# 2  6944451730440604672  Realistic TinTin hits different #ai #history #...
# 3  6839530375820233728  THIS IS IMPOSSIBLE!! #foryoupage #ai #robot #f...
# 4  6858712997263576064                                                #ai
#
#    createTime                                              video  \
# 0  1616441686  {'id': '6942564167555501318', 'height': 1024, ...
# 1  1608401967  {'id': '6908033755215121670', 'height': 960, '...
# 2  1616881169  {'id': '6944451730440604933', 'height': 1024, ...
# 3  1592452264  {'id': '6839530375820233989', 'height': 1024, ...
# 4  1596918567  {'id': '6858712997263576325', 'height': 1024, ...
#
#                                               author  \
# 0  {'id': '6731645561101698053', 'uniqueId': 'huw...
# 1  {'id': '6527686', 'uniqueId': 'matthewpaquette...
# 2  {'id': '6621100435779207174', 'uniqueId': 'ton...
# 3  {'id': '6591795803868954630', 'uniqueId': 'jac...
# 4  {'id': '6747587655967966213', 'uniqueId': 'sam...
#
#                                                music  \
# 0  {'id': '6715195986316101634', 'title': 'Back I...
# 1  {'id': '6839324086548563969', 'title': 'Blade ...
# 2  {'id': '6839324086548563969', 'title': 'Blade ...
# 3  {'id': '6839530321172630277', 'title': 'AI IS ...
# 4  {'id': '6858713012384172806', 'title': 'origin...
#
#                                           challenges  \
# 0  [{'id': '13037', 'title': 'ironman', 'desc': '...
# 1  [{'id': '183145', 'title': 'ai', 'desc': '', '...
# 2  [{'id': '183145', 'title': 'ai', 'desc': '', '...
# 3  [{'id': '88764338', 'title': 'foryoupage', 'de...
# 4  [{'id': '183145', 'title': 'ai', 'desc': '', '...
#
#                                                stats             duetInfo  \
# 0  {'diggCount': 2300000, 'shareCount': 12800, 'c...  {'duetFromId': '0'}
# 1  {'diggCount': 2300000, 'shareCount': 45900, 'c...  {'duetFromId': '0'}
# 2  {'diggCount': 2200000, 'shareCount': 16400, 'c...  {'duetFromId': '0'}
# 3  {'diggCount': 2000000, 'shareCount': 46000, 'c...  {'duetFromId': '0'}
# 4  {'diggCount': 1900000, 'shareCount': 30400, 'c...  {'duetFromId': '0'}
#
#    originalItem  ...  privateItem duetEnabled  stitchEnabled  shareEnabled  \
# 0         False  ...        False        True           True          True
# 1         False  ...        False        True           True          True
# 2         False  ...        False        True           True          True
# 3         False  ...        False        True           True          True
# 4         False  ...        False        True           True          True
#
#                                       stickersOnItem   isAd  duetDisplay  \
# 0  [{'stickerType': 4, 'stickerText': ['BUILDING ...  False            0
# 1  [{'stickerType': 4, 'stickerText': ['These peo...  False            0
# 2  [{'stickerType': 4, 'stickerText': ['What Famo...  False            0
# 3  [{'stickerType': 4, 'stickerText': ['THIS IS I...  False            0
# 4                                                NaN  False            0
#
#    stitchDisplay                                     effectStickers warnInfo
# 0              0                                                NaN      NaN
# 1              0                                                NaN      NaN
# 2              0                                                NaN      NaN
# 3              0                                                NaN      NaN
# 4              0  [{'name': 'Green Screen', 'ID': '279660'}, {'n...      NaN
#
# [5 rows x 30 columns]

# %%
df.to_csv("tiktokdata.csv")

# %% [markdown]
# # Create Helper Function

# %%
import json

# %%
with open ('export.json','r') as f:
    data=json.load(f)

# %%
nested_values=['video','author','music','stats','authorStats','challenges','duetInfo','textExtra','stickersOnItem']
skip_values=['challenges','duetInfo','textExtra','stickersOnItem']

# %%
# create blank dictionary 
flattened_data={}
# loop through each video 
for idx,value in enumerate( data):
    flattened_data[idx]={}
    # loop through each value in each video
    for prop_idx,prop_value in value.items():
        # check if nested 
        if prop_idx in nested_values:
            if prop_idx in skip_values:
                pass
            else:
                # loop through properties 
                for nested_idx,nested_value in prop_value.items():
                    flattened_data[idx][prop_idx+'_'+nested_idx]=nested_value
        # if not nested add to flattened dict        
        else:
            flattened_data[idx][prop_idx]=prop_value

# %%
df_test=pd.DataFrame.from_dict(flattened_data,orient="index")

# %%
df_test.head()
# Out:
#                     id                                               desc  \
# 0  6942564167555501318  What do you mean?! #ironman #marvel #fyp #popv...
# 1  6908033755215121670           These people do not exist 🤯 #AI #ML #FYP
# 2  6944451730440604933  Realistic TinTin hits different #ai #history #...
# 3  6839530375820233989  THIS IS IMPOSSIBLE!! #foryoupage #ai #robot #f...
# 4  6858712997263576325                                                #ai
#
#    createTime             video_id  video_height  video_width  video_duration  \
# 0  1616441686  6942564167555501318          1024          576              28
# 1  1608401967  6908033755215121670           960          540              30
# 2  1616881169  6944451730440604933          1024          576              29
# 3  1592452264  6839530375820233989          1024          576              20
# 4  1596918567  6858712997263576325          1024          576              58
#
#   video_ratio                                        video_cover  \
# 0        720p  https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
# 1        720p  https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
# 2        720p  https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
# 3        720p  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 4        720p  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
#
#                                    video_originCover  ... authorStats_heart  \
# 0  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           9400000
# 1  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           2800000
# 2  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           7100000
# 3  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           3000000
# 4  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...          19300000
#
#   privateItem duetEnabled stitchEnabled shareEnabled   isAd duetDisplay  \
# 0       False        True          True         True  False           0
# 1       False        True          True         True  False           0
# 2       False        True          True         True  False           0
# 3       False        True          True         True  False           0
# 4       False        True          True         True  False           0
#
#   stitchDisplay                                     effectStickers warnInfo
# 0             0                                                NaN      NaN
# 1             0                                                NaN      NaN
# 2             0                                                NaN      NaN
# 3             0                                                NaN      NaN
# 4             0  [{'name': 'Green Screen', 'ID': '279660'}, {'n...      NaN
#
# [5 rows x 78 columns]

# %%
df_test.to_csv("analytics.csv")
